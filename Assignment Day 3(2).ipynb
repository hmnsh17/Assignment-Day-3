# %%
for num in range(1,200):
    if num%2==0:
        print(num, "is not Prime no")
    else:
        print(num, "is Prime no")
# Out:
# 1 is Prime no
# 2 is not Prime no
# 3 is Prime no
# 4 is not Prime no
# 5 is Prime no
# 6 is not Prime no
# 7 is Prime no
# 8 is not Prime no
# 9 is Prime no
# 10 is not Prime no
# 11 is Prime no
# 12 is not Prime no
# 13 is Prime no
# 14 is not Prime no
# 15 is Prime no
# 16 is not Prime no
# 17 is Prime no
# 18 is not Prime no
# 19 is Prime no
# 20 is not Prime no
# 21 is Prime no
# 22 is not Prime no
# 23 is Prime no
# 24 is not Prime no
# 25 is Prime no
# 26 is not Prime no
# 27 is Prime no
# 28 is not Prime no
# 29 is Prime no
# 30 is not Prime no
# 31 is Prime no
# 32 is not Prime no
# 33 is Prime no
# 34 is not Prime no
# 35 is Prime no
# 36 is not Prime no
# 37 is Prime no
# 38 is not Prime no
# 39 is Prime no
# 40 is not Prime no
# 41 is Prime no
# 42 is not Prime no
# 43 is Prime no
# 44 is not Prime no
# 45 is Prime no
# 46 is not Prime no
# 47 is Prime no
# 48 is not Prime no
# 49 is Prime no
# 50 is not Prime no
# 51 is Prime no
# 52 is not Prime no
# 53 is Prime no
# ...
